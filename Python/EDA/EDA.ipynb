# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("/content/train.csv")

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.dropna()
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("/content/Server data.csv")

# %%
df.head()
# Out:
#    Year  Facility_ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 2  2021  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 3  2022  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 4  2023  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
# 2   Spain  Enterprise/Standard                   6.47  1.928
# 3   Spain  Enterprise/Standard                   6.59  1.897
# 4   Spain  Enterprise/Standard                   6.70  1.869
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# ...

# %%
df.tail()
# Out:
#         Year  Facility_ID       Facility_Name  \
# 126765  2021  DC-31D8B15E  ICS_DataCenter_216
# 126766  2022  DC-31D8B15E  ICS_DataCenter_216
# 126767  2023  DC-31D8B15E  ICS_DataCenter_216
# 126768  2024  DC-31D8B15E  ICS_DataCenter_216
# 126769  2025  DC-31D8B15E  ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 126765  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126766  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126767  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126768  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126769  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
#
#               Facility_Type  Estimated_Capacity_MW    PUE Cooling_System_Type  \
# 126765  Enterprise/Standard                  14.51  1.495         Evaporative
# ...

# %%
df.sample()
# Out:
#        Year  Facility_ID                 Facility_Name  \
# 79517  2023  DC-28C4034B  Los Angeles LAX1 Data Center
#
#                     Owner_Company     City        Country  \
# 79517  DigiCo Infrastructure REIT  Unknown  United States
#
#              Facility_Type  Estimated_Capacity_MW    PUE Cooling_System_Type  \
# 79517  Enterprise/Standard                   5.39  1.589          Air Cooled
#
#        WUE_L_per_kWh  Daily_Electricity_Usage_MWh  Daily_Water_Usage_Gallons  \
# 79517           0.19                       179.55                     5685.6
#
#       Surrounding_Water_Stress_Tier
# 79517                           Low

# %%
df.shape
# Out:
# (126770, 14)

# %%
df.size
# Out:
# 1774780

# %%
df.columns
# Out:
# Index(['Year', 'Facility_ID', 'Facility_Name', 'Owner_Company', 'City',
#        'Country', 'Facility_Type', 'Estimated_Capacity_MW', 'PUE',
#        'Cooling_System_Type', 'WUE_L_per_kWh', 'Daily_Electricity_Usage_MWh',
#        'Daily_Water_Usage_Gallons', 'Surrounding_Water_Stress_Tier'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126770, step=1)

# %%
df.dtypes
# Out:
# Year                               int64
# Facility_ID                       object
# Facility_Name                     object
# Owner_Company                     object
# City                              object
# Country                           object
# Facility_Type                     object
# Estimated_Capacity_MW            float64
# PUE                              float64
# Cooling_System_Type               object
# WUE_L_per_kWh                    float64
# Daily_Electricity_Usage_MWh      float64
# Daily_Water_Usage_Gallons        float64
# Surrounding_Water_Stress_Tier     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126770 entries, 0 to 126769
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Year                           126770 non-null  int64
#  1   Facility_ID                    126770 non-null  object
#  2   Facility_Name                  126770 non-null  object
#  3   Owner_Company                  126770 non-null  object
#  4   City                           126770 non-null  object
#  5   Country                        126770 non-null  object
#  6   Facility_Type                  126770 non-null  object
#  7   Estimated_Capacity_MW          126770 non-null  float64
#  8   PUE                            126770 non-null  float64
#  9   Cooling_System_Type            126770 non-null  object
#  10  WUE_L_per_kWh                  126770 non-null  float64
#  11  Daily_Electricity_Usage_MWh    126770 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Year  Estimated_Capacity_MW            PUE  WUE_L_per_kWh  \
# count  126770.000000          126770.000000  126770.000000  126770.000000
# mean     2022.000000              23.075117       1.637746       0.820596
# std         2.000008              45.847195       0.190833       0.925481
# min      2019.000000               1.000000       1.057000       0.001000
# 25%      2020.000000               5.450000       1.518000       0.139000
# 50%      2022.000000               9.870000       1.643000       0.232000
# 75%      2024.000000              14.180000       1.787000       1.654000
# max      2025.000000             562.890000       2.000000       3.000000
#
#        Daily_Electricity_Usage_MWh  Daily_Water_Usage_Gallons
# count                126770.000000               1.267700e+05
# mean                    605.222368               1.312182e+05
# std                    1040.061940               3.979629e+05
# ...

# %%
df.isnull()
# Out:
#          Year  Facility_ID  Facility_Name  Owner_Company   City  Country  \
# 0       False        False          False          False  False    False
# 1       False        False          False          False  False    False
# 2       False        False          False          False  False    False
# 3       False        False          False          False  False    False
# 4       False        False          False          False  False    False
# ...       ...          ...            ...            ...    ...      ...
# 126765  False        False          False          False  False    False
# 126766  False        False          False          False  False    False
# 126767  False        False          False          False  False    False
# 126768  False        False          False          False  False    False
# 126769  False        False          False          False  False    False
#
#         Facility_Type  Estimated_Capacity_MW    PUE  Cooling_System_Type  \
# ...

# %%
df.notnull()
# Out:
#         Year  Facility_ID  Facility_Name  Owner_Company  City  Country  \
# 0       True         True           True           True  True     True
# 1       True         True           True           True  True     True
# 2       True         True           True           True  True     True
# 3       True         True           True           True  True     True
# 4       True         True           True           True  True     True
# ...      ...          ...            ...            ...   ...      ...
# 126765  True         True           True           True  True     True
# 126766  True         True           True           True  True     True
# 126767  True         True           True           True  True     True
# 126768  True         True           True           True  True     True
# 126769  True         True           True           True  True     True
#
#         Facility_Type  Estimated_Capacity_MW   PUE  Cooling_System_Type  \
# ...

# %%
df['Daily_Water_Usage_Gallons'].sum()
# Out:
# np.float64(16634526746.019999)

# %%
df.dropna()
# Out:
#         Year  Facility_ID               Facility_Name  \
# 0       2019  DC-D2763E00  NAP de las Americas Madrid
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 2       2021  DC-D2763E00  NAP de las Americas Madrid
# 3       2022  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 0                                               Terremark   Madrid    Spain
# 1                                               Terremark   Madrid    Spain
# 2                                               Terremark   Madrid    Spain
# ...

# %%
df.fillna("NULL")
# Out:
#         Year  Facility_ID               Facility_Name  \
# 0       2019  DC-D2763E00  NAP de las Americas Madrid
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 2       2021  DC-D2763E00  NAP de las Americas Madrid
# 3       2022  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 0                                               Terremark   Madrid    Spain
# 1                                               Terremark   Madrid    Spain
# 2                                               Terremark   Madrid    Spain
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126765    False
# 126766    False
# 126767    False
# 126768    False
# 126769    False
# Length: 126770, dtype: bool

# %%
df.drop_duplicates()
# Out:
#         Year  Facility_ID               Facility_Name  \
# 0       2019  DC-D2763E00  NAP de las Americas Madrid
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 2       2021  DC-D2763E00  NAP de las Americas Madrid
# 3       2022  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 0                                               Terremark   Madrid    Spain
# 1                                               Terremark   Madrid    Spain
# 2                                               Terremark   Madrid    Spain
# ...

# %%
df.nunique()
# Out:
# Year                                  7
# Facility_ID                       18110
# Facility_Name                     16286
# Owner_Company                      4180
# City                               2513
# Country                             344
# Facility_Type                         3
# Estimated_Capacity_MW             13888
# PUE                                 941
# Cooling_System_Type                   3
# WUE_L_per_kWh                      2233
# Daily_Electricity_Usage_MWh       65027
# Daily_Water_Usage_Gallons        124815
# Surrounding_Water_Stress_Tier         3
# dtype: int64

# %%
print(df['Facility_ID'].unique())
print(df['Owner_Company'].unique())
print(df['Surrounding_Water_Stress_Tier'].unique())
# Out:
# ['DC-D2763E00' 'DC-97AB1D99' 'DC-F1A55D5B' ... 'DC-6ED48AF1' 'DC-69F89A63'
#  'DC-31D8B15E']
# ['Terremark' 'StarHub Ltd.' 'GTS Telecom SRL' ... 'Turnket' 'Teknet'
#  'ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLERİ A.Ş.']
# ['Low' 'High' 'Medium']

# %%
df["Facility_ID"].value_counts()
# Out:
# Facility_ID
# DC-31D8B15E    7
# DC-D2763E00    7
# DC-97AB1D99    7
# DC-F1A55D5B    7
# DC-40C11C98    7
#               ..
# DC-B01BDE72    7
# DC-C9C3C70C    7
# DC-7CD78B51    7
# DC-7AD2ECD4    7
# DC-BFF5E40B    7
# Name: count, Length: 18110, dtype: int64

# %%
df.sort_values("Daily_Water_Usage_Gallons")
# Out:
#        Year  Facility_ID                        Facility_Name  \
# 39817  2020  DC-E9C3E2E3  The Nairobi City County Data Center
# 38408  2025  DC-C8E882F0                               Sydney
# 57713  2024  DC-09B35579    EdgeConneX Santa Clara - EDCSVC01
# 38405  2022  DC-C8E882F0                               Sydney
# 38403  2020  DC-C8E882F0                               Sydney
# ...     ...          ...                                  ...
# 19655  2025  DC-EB191B73                            Indonesia
# 63342  2025  DC-8ED6CAD3          Amazon AWS BWI - Building 4
# 55649  2025  DC-426B4213             Meta DeKalb - Building 5
# 67927  2025  DC-D8E39B33                AWS 22 Delivery Drive
# 51260  2025  DC-2534A814  Amazon AWS IAD - 24359 Racefield Ln
#
#                  Owner_Company          City        Country  \
# 39817  The Nairobi City County  (020)2222821        Unknown
# 38408             NetDocuments        Sydney      Australia
# ...

# %%
print(df['Daily_Water_Usage_Gallons'].min())
print(df['Daily_Water_Usage_Gallons'].max())
print(df['Daily_Water_Usage_Gallons'].mean())
print(df['Daily_Water_Usage_Gallons'].median())
print(df['Daily_Water_Usage_Gallons'].mode())
print(df['Daily_Water_Usage_Gallons'].std())
print(df['Daily_Water_Usage_Gallons'].var())
# Out:
# 224.01
# 7585092.35
# 131218.164755226
# 12181.295
# 0       563.58
# 1      1320.56
# 2      1365.46
# 3      1408.85
# 4      1528.18
# 5      1694.40
# 6      1727.40
# 7      1929.76
# 8      2091.36
# 9      2129.71
# 10     2157.75
# 11     2458.21
# 12     2620.97
# 13     2734.67
# 14     2912.10
# 15     2979.37
# 16     3641.48
# 17     3918.32
# 18     4103.45
# 19     4185.57
# 20     4205.02
# 21     4245.77
# 22     4400.12
# 23     4535.78
# 24     4548.18
# 25     4560.90
# 26     4664.55
# 27     4883.54
# 28     5208.73
# 29     5712.17
# 30     7633.27
# 31     8420.65
# 32    11834.97
# Name: Daily_Water_Usage_Gallons, dtype: float64
# 397962.8999820984
# 158374469762.16162

# %%
df['Daily_Water_Usage_Gallons'].corr(df['Daily_Electricity_Usage_MWh'])
# Out:
# np.float64(0.7916958121561101)

# %%
print(df['Daily_Water_Usage_Gallons'].cov(df['Daily_Electricity_Usage_MWh']))
# Out:
# 327687698.8539946

# %%
df.groupby(by = 'Facility_Type')['Daily_Water_Usage_Gallons'].mean()
# Out:
# Facility_Type
# Colocation             2.983745e+05
# Enterprise/Standard    3.003673e+04
# Hyperscale/AI          1.074522e+06
# Name: Daily_Water_Usage_Gallons, dtype: float64

# %%
df['Facility_Name'].count()
# Out:
# np.int64(126770)

# %%
df.loc[2]
# Out:
# Year                                                   2021
# Facility_ID                                     DC-D2763E00
# Facility_Name                    NAP de las Americas Madrid
# Owner_Company                                     Terremark
# City                                                 Madrid
# Country                                               Spain
# Facility_Type                           Enterprise/Standard
# Estimated_Capacity_MW                                  6.47
# PUE                                                   1.928
# Cooling_System_Type                             Evaporative
# WUE_L_per_kWh                                          1.45
# Daily_Electricity_Usage_MWh                          266.85
# Daily_Water_Usage_Gallons                          53026.35
# Surrounding_Water_Stress_Tier                           Low
# Name: 2, dtype: object

# %%
df.iloc[-1]
# Out:
# Year                                                                          2025
# Facility_ID                                                            DC-31D8B15E
# Facility_Name                                                   ICS_DataCenter_216
# Owner_Company                    ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...
# City                                                                       Unknown
# Country                                                                    Türkiye
# Facility_Type                                                  Enterprise/Standard
# Estimated_Capacity_MW                                                        15.58
# PUE                                                                          1.431
# Cooling_System_Type                                                    Evaporative
# WUE_L_per_kWh                                                                2.217
# ...

# %%
df.query("Daily_Electricity_Usage_MWh > 200")
# Out:
#         Year  Facility_ID               Facility_Name  \
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 2       2021  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# 6       2025  DC-D2763E00  NAP de las Americas Madrid
# 7       2019  DC-97AB1D99            Central Office 2
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company       City  \
# 1                                               Terremark     Madrid
# 2                                               Terremark     Madrid
# 4                                               Terremark     Madrid
# ...

# %%
df['PUE'].rename('Power Usage Effectiveness')
# Out:
# 0         1.975
# 1         1.967
# 2         1.928
# 3         1.897
# 4         1.869
#           ...
# 126765    1.495
# 126766    1.485
# 126767    1.473
# 126768    1.450
# 126769    1.431
# Name: Power Usage Effectiveness, Length: 126770, dtype: float64

# %%
df.drop(2)
# Out:
#         Year  Facility_ID               Facility_Name  \
# 0       2019  DC-D2763E00  NAP de las Americas Madrid
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 3       2022  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# 5       2024  DC-D2763E00  NAP de las Americas Madrid
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 0                                               Terremark   Madrid    Spain
# 1                                               Terremark   Madrid    Spain
# 3                                               Terremark   Madrid    Spain
# ...

# %%
df.hist('Daily_Electricity_Usage_MWh',bins =200)
# Out:
# array([[<Axes: title={'center': 'Daily_Electricity_Usage_MWh'}>]],
#       dtype=object)

# %%
df.boxplot('Daily_Electricity_Usage_MWh')
# Out:
# <Axes: >

# %%
df.boxplot('Daily_Electricity_Usage_MWh',by = 'Facility_Type')
# Out:
# <Axes: title={'center': 'Daily_Electricity_Usage_MWh'}, xlabel='Facility_Type'>

# %%
df.hist(column='Daily_Electricity_Usage_MWh', by='Facility_Type', bins=50)
# Out:
# array([[<Axes: title={'center': 'Colocation'}>,
#         <Axes: title={'center': 'Enterprise/Standard'}>],
#        [<Axes: title={'center': 'Hyperscale/AI'}>, <Axes: >]],
#       dtype=object)

# %%
sns.scatterplot(x='Daily_Electricity_Usage_MWh', y='Facility_Type', data=df)
# Out:
# <Axes: xlabel='Daily_Electricity_Usage_MWh', ylabel='Facility_Type'>

# %%
sns.countplot(y='Facility_Type', data=df)
# Out:
# <Axes: xlabel='count', ylabel='Facility_Type'>

# %%
sns.pairplot(data=df, vars=['Daily_Electricity_Usage_MWh'], hue='Facility_Type')

# %%
sns.heatmap(df.corr(numeric_only=True)[['Daily_Electricity_Usage_MWh']],annot = True, cmap='coolwarm')
plt.show()
